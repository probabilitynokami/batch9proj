// %%
using Microsoft.EntityFrameworkCore;
// Out:
// (1,17): error CS0234: The type or namespace name 'EntityFrameworkCore' does not exist in the namespace 'Microsoft' (are you missing an assembly reference?)

// %%
var a = 1;

// %%
a+a
// Out:
// <div class="dni-plaintext"><pre>2</pre></div><style>
// .dni-code-hint {
//     font-style: italic;
//     overflow: hidden;
//     white-space: nowrap;
// }
// .dni-treeview {
//     white-space: nowrap;
// }
// .dni-treeview td {
//     vertical-align: top;
//     text-align: start;
// }
// details.dni-treeview {
//     padding-left: 1em;
// }
// table td {
//     text-align: start;
// }
// table tr {
//     vertical-align: top;
//     margin: 0em 0px;
// }
// table tr td pre
// {
//     vertical-align: top !important;
//     margin: 0em 0px !important;
// }
// table th {
//     text-align: start;
// }
// </style>

// %%
a+a+a+a+a
// Out:
// <div class="dni-plaintext"><pre>5</pre></div><style>
// .dni-code-hint {
//     font-style: italic;
//     overflow: hidden;
//     white-space: nowrap;
// }
// .dni-treeview {
//     white-space: nowrap;
// }
// .dni-treeview td {
//     vertical-align: top;
//     text-align: start;
// }
// details.dni-treeview {
//     padding-left: 1em;
// }
// table td {
//     text-align: start;
// }
// table tr {
//     vertical-align: top;
//     margin: 0em 0px;
// }
// table tr td pre
// {
//     vertical-align: top !important;
//     margin: 0em 0px !important;
// }
// table th {
//     text-align: start;
// }
// </style>

// %%
List<int> x = [a,a,a,a,a,a,a,a,a];

// %%
#r ".\obj\Debug\net8.0\ref\EntityFramework.dll"

// %%
using Microsoft.EntityFramework;
// Out:
// (1,17): error CS0234: The type or namespace name 'EntityFramework' does not exist in the namespace 'Microsoft' (are you missing an assembly reference?)

// %%
#r "nuget:Microsoft.EntityFramework"
using Microsoft.EntityFramework;
// Out:
// <div><div></div><div></div><div></div></div>
// C:\Users\Batch 9\.packagemanagement\nuget\Projects\23084--7b5916ff-9812-4870-b949-71726fdd937b\Project.fsproj : error NU1101: Unable to find package Microsoft.EntityFramework. No packages exist with this id in source(s): C:\Program Files\dotnet\sdk\8.0.201\FSharp\library-packs, nuget.org
